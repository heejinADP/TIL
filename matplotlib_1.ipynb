# %% [markdown]
# # Functions of matplotlib 1

# %%
import matplotlib as mpl
import matplotlib.pylab as plt
import numpy as np

# %%
plt.plot([10,20,30,40],[1,4,9,16],'rs--')
plt.xlim(0,50)
plt.ylim(-10,30)
x=np.linspace(-np.pi,np.pi,256)
plt.plot(x,c)
plt.show()

# %%
t=np.arange(0.,5.,0.2)
plt.plot(t,t,'r--',t,0.5*t**2, 'bs:',t,0.2*t**3,'g^-')
plt.show()

# %%
x=np.linspace(-np.pi, np.pi, 256)
c,s=np.cos(x),np.sin(x)
plt.plot(x,c,ls="--",label="cosine")
plt.plot(x,s,ls="--",label="sine")
plt.legend()
plt.xlabel("xlabel")
plt.ylabel("ylabel")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
f1=plt.figure(figsize=(10,2))
plt.plot(np.random.randn(100))
f2=plt.figure(1)
plt.plot([1,2,3,4],'ro:')
f2=plt.gcf()
print(f1,id(f1))
print(f2,id(f2))
plt.show()
# Out:
# Figure(720x144) 1820354037912
# Figure(720x144) 1820354037912

# %%
x1=np.linspace(0.0,5.0)
x2=np.linspace(0.0,2.0)
y1=np.cos(2*np.pi*x1)*np.exp(-x1)
y2=np.cos(2*np.pi*x2)
ax1=plt.subplot(2,1,1)
plt.plot(x1,y1,'yo-')
ax2=plt.subplot(2,1,2)
plt.plot(x2,y2,'r.-')
plt.show()

# %%
a=np.random.randint(0,30,(5,6))
print(a)
print("각 열의 합 : ", np.sum(a,axis=0))
print("각 열의 평균 : ", np.average(a,axis=0))
# Out:
# [[16 11 16 20  7 25]
#  [ 3 18 13 18  1 12]
#  [ 6 22  0  8 22  4]
#  [15 14  2 25 17 26]
#  [29 26  4  9  2  2]]
# 각 열의 합 :  [69 91 35 80 49 69]
# 각 열의 평균 :  [13.8 18.2  7.  16.   9.8 13.8]
